# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("student.csv")
df.head(10)
# Out:
#    id         name  class  mark  gender
# 0   1     John Deo   Four    75  female
# 1   2     Max Ruin  Three    85    male
# 2   3       Arnold  Three    55    male
# 3   4   Krish Star   Four    60  female
# 4   5    John Mike   Four    60  female
# 5   6    Alex John   Four    55    male
# 6   7  My John Rob  Fifth    78    male
# 7   8       Asruid   Five    85    male
# 8   9      Tes Qry    Six    78    male
# 9  10     Big John   Four    55  female

# %%
df["class"]
# Out:
# 0      Four
# 1     Three
# 2     Three
# 3      Four
# 4      Four
# 5      Four
# 6     Fifth
# 7      Five
# 8       Six
# 9      Four
# 10      Six
# 11      Six
# 12    Seven
# 13    Seven
# 14     Four
# 15     Four
# 16      Six
# 17     Five
# 18     Nine
# 19     Nine
# 20     Four
# 21    Seven
# 22    Eight
# 23    Seven
# 24    Seven
# 25    Seven
# 26    Three
# 27    Seven
# 28    Seven
# 29      Six
# 30     Four
# 31    Seven
# 32      Six
# 33    Seven
# 34      Six
# Name: class, dtype: object

# %%
df[["name","class"]]
# Out:
#            name  class
# 0      John Deo   Four
# 1      Max Ruin  Three
# 2        Arnold  Three
# 3    Krish Star   Four
# 4     John Mike   Four
# 5     Alex John   Four
# 6   My John Rob  Fifth
# 7        Asruid   Five
# 8       Tes Qry    Six
# 9      Big John   Four
# 10       Ronald    Six
# 11        Recky    Six
# 12          Kty  Seven
# 13         Bigy  Seven
# 14     Tade Row   Four
# 15        Gimmy   Four
# 16        Tumyu    Six
# 17        Honny   Five
# 18        Tinny   Nine
# 19       Jackly   Nine
# 20   Babby John   Four
# 21       Reggid  Seven
# 22        Herod  Eight
# 23    Tiddy Now  Seven
# 24     Giff Tow  Seven
# 25       Crelea  Seven
# 26     Big Nose  Three
# 27    Rojj Base  Seven
# 28  Tess Played  Seven
# 29    Reppy Red    Six
# 30  Marry Toeey   Four
# 31    Binn Rott  Seven
# 32    Kenn Rein    Six
# 33     Gain Toe  Seven
# 34   Rows Noump    Six

# %%
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df[0:2]
# Out:
#    id      name  class  mark  gender
# 0   1  John Deo   Four    75  female
# 1   2  Max Ruin  Three    85    male

# %%
df.loc[1]
# Out:
# id               2
# name      Max Ruin
# class        Three
# mark            85
# gender        male
# Name: 1, dtype: object

# %%
df.loc[1,"mark"]
# Out:
# np.int64(85)

# %%
df.loc[[0,2], ["name","gender"]]
# Out:
#        name  gender
# 0  John Deo  female
# 2    Arnold    male

# %%
df.iloc[1]
# Out:
# id               2
# name      Max Ruin
# class        Three
# mark            85
# gender        male
# Name: 1, dtype: object

# %%
df.iloc[1,1]
# Out:
# 'Max Ruin'

# %%
df.iloc[0:2, 0:2]
# Out:
#    id      name
# 0   1  John Deo
# 1   2  Max Ruin

# %%
print(df[df["mark"]>90])
# Out:
#     id       name class  mark  gender
# 11  12      Recky   Six    94  female
# 32  33  Kenn Rein   Six    96  female

# %% [markdown]
# Select a single column from a DataFrame.

# %%
df["mark"]
# Out:
# 0     75
# 1     85
# 2     55
# 3     60
# 4     60
# 5     55
# 6     78
# 7     85
# 8     78
# 9     55
# 10    89
# 11    94
# 12    88
# 13    88
# 14    88
# 15    88
# 16    54
# 17    75
# 18    18
# 19    65
# 20    69
# 21    55
# 22    79
# 23    78
# 24    88
# 25    79
# 26    81
# 27    86
# 28    55
# 29    79
# 30    88
# 31    90
# 32    96
# 33    69
# 34    88
# Name: mark, dtype: int64

# %% [markdown]
# Select specific rows using iloc[].

# %%
df.iloc[2]
# Out:
# id             3
# name      Arnold
# class      Three
# mark          55
# gender      male
# Name: 2, dtype: object

# %% [markdown]
# Apply conditional filtering (id > 30).

# %%
df[df["id"]>30]
# Out:
#     id         name  class  mark  gender
# 30  31  Marry Toeey   Four    88    male
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 33  34     Gain Toe  Seven    69    male
# 34  35   Rows Noump    Six    88  female

# %% [markdown]
# Select the first 3 rows of a DataFrame.

# %%
df[0:3]
# Out:
#    id      name  class  mark  gender
# 0   1  John Deo   Four    75  female
# 1   2  Max Ruin  Three    85    male
# 2   3    Arnold  Three    55    male

# %% [markdown]
# Select only the Name column.

# %%
df["name"]
# Out:
# 0        John Deo
# 1        Max Ruin
# 2          Arnold
# 3      Krish Star
# 4       John Mike
# 5       Alex John
# 6     My John Rob
# 7          Asruid
# 8         Tes Qry
# 9        Big John
# 10         Ronald
# 11          Recky
# 12            Kty
# 13           Bigy
# 14       Tade Row
# 15          Gimmy
# 16          Tumyu
# 17          Honny
# 18          Tinny
# 19         Jackly
# 20     Babby John
# 21         Reggid
# 22          Herod
# 23      Tiddy Now
# 24       Giff Tow
# 25         Crelea
# 26       Big Nose
# 27      Rojj Base
# 28    Tess Played
# 29      Reppy Red
# 30    Marry Toeey
# 31      Binn Rott
# 32      Kenn Rein
# 33       Gain Toe
# 34     Rows Noump
# Name: name, dtype: object

# %% [markdown]
# Filter rows where gender == male

# %%
df[df["gender"] == "male"]
# Out:
#     id         name  class  mark gender
# 1    2     Max Ruin  Three    85   male
# 2    3       Arnold  Three    55   male
# 5    6    Alex John   Four    55   male
# 6    7  My John Rob  Fifth    78   male
# 7    8       Asruid   Five    85   male
# 8    9      Tes Qry    Six    78   male
# 14  15     Tade Row   Four    88   male
# 15  16        Gimmy   Four    88   male
# 16  17        Tumyu    Six    54   male
# 17  18        Honny   Five    75   male
# 18  19        Tinny   Nine    18   male
# 22  23        Herod  Eight    79   male
# 23  24    Tiddy Now  Seven    78   male
# 24  25     Giff Tow  Seven    88   male
# 25  26       Crelea  Seven    79   male
# 28  29  Tess Played  Seven    55   male
# 30  31  Marry Toeey   Four    88   male
# 33  34     Gain Toe  Seven    69   male

# %% [markdown]
# Select rows 2–4 and columns Name and Age using iloc[].

# %%
df.loc[2:5, ["name", "mark"]]
# Out:
#          name  mark
# 2      Arnold    55
# 3  Krish Star    60
# 4   John Mike    60
# 5   Alex John    55

# %% [markdown]
# Filter rows where marks is between 50 and 70

# %%
df[(df["mark"]>=50) & (df["mark"]<=70)]
# Out:
#     id         name  class  mark  gender
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 9   10     Big John   Four    55  female
# 16  17        Tumyu    Six    54    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# 28  29  Tess Played  Seven    55    male
# 33  34     Gain Toe  Seven    69    male
